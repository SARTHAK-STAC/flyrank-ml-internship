# %% [markdown]
# <a href="https://colab.research.google.com/github/SARTHAK-STAC/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/SARTHAK-STAC/flyrank-ml-internship.git
# %cd flyrank-ml-internship
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 124, done.
# remote: Counting objects: 100% (124/124), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 124 (delta 39), reused 92 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (124/124), 1.85 MiB | 8.09 MiB/s, done.
# Resolving deltas: 100% (39/39), done.
# /content/flyrank-ml-internship/flyrank-ml-internship

# %%
# !ls
# Out:
# AGENTS.md  DATA_USE.md	LICENSE    README.md	     SETUP.md	 work
# CLAUDE.md  docs		notebooks  requirements.txt  skills
# data	   GUIDE.md	outputs    scripts	     submission

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/SARTHAK-STAC/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# I chose the Refresh / Content Opportunity Scoring lane. This is primarily a scoring and ranking task because the goal is to assign a priority score to each content page and rank pages according to how strongly they should be considered for a content refresh. The model supports decision-making rather than making automatic changes.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# The ideal target is whether a content page should be refreshed. Since there is no direct label for this, I will use a proxy based on historical search performance and engagement signals such as impressions, clicks, CTR, average position, and user engagement. These observed metrics help estimate which pages are likely to benefit from review.

# %%
print("Target: Content refresh priority")
print("Proxy: Historical search performance and engagement metrics")
# Out:
# Target: Content refresh priority
# Proxy: Historical search performance and engagement metrics

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# A successful model should rank high-priority pages ahead of low-priority pages so that content managers can focus their effort where it is most valuable. I will evaluate the model using ranking quality and classification metrics such as Precision, Recall, and F1-score.

# %%
print("Evaluation metrics: Precision, Recall, F1-score")
# Out:
# Evaluation metrics: Precision, Recall, F1-score

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# Each row in the dataset represents one content page together with its search performance, content features, and engagement metrics. The model evaluates one page at a time and assigns it a refresh priority score.

# %%
import pandas as pd
from pathlib import Path

csv_files = list(Path("data").rglob("*.csv"))

print("CSV files:")
for f in csv_files:
    print("-", f)

df = pd.read_csv(csv_files[0])

print("\nRows:", len(df))
print("Columns:", len(df.columns))

display(df.head())
# Out:
# CSV files:
# - data/raw/content_refresh_anonymized.csv
#
# Rows: 30000
# Columns: 44
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# A simple rule such as "refresh pages with CTR below a threshold" ignores many interacting factors. Machine learning can learn relationships between search performance, engagement, content quality, and other features at the same time. This allows the model to produce more accurate and consistent prioritization than a single fixed rule.

# %%
print("ML can combine multiple features better than a fixed threshold rule.")
# Out:
# ML can combine multiple features better than a fixed threshold rule.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
